# %% [markdown]
# # 특성값을 이용하여 BMI 값을 예측하기(회귀)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:/Users/tansy/Ai/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # Outcome(레이블) 제거

# %%
df = df.drop('Outcome', axis=1)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %% [markdown]
# # 상관관계 행렬을 히트맵으로 표시

# %%
#상관 관계 행렬
# 0.3 이상인 경우 상관관계가 있고, 0.7이상이면 아주 높음

df_corr=df.corr() # 상관관계 행렬 

#히트맵
plt.figure(figsize=(10,10)) 
sns.set(font_scale=0.8)  
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# BMI와 높은 건  SkinThickness (0.39)

# %% [markdown]
# # 1. 데이터 준비

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = df.drop('BMI',axis=1) 
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y = df['BMI'] 
y.head()
# Out:
# 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# Name: BMI, dtype: float64

# %% [markdown]
# # 딥러닝 입력을 위해 Numpy로 변환

# %%
X = X.values
X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.   ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.   ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.   ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ..., 112.   ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.   ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.   ,   0.315,  23.   ]])

# %% [markdown]
# # 훈련, 검증 데이터셋 준비

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((614, 7), (614,), (154, 7), (154,))

# %%
input_dim = X_train.shape[1]
print(input_dim)
# Out:
# 7

# %% [markdown]
# # 회귀 모델 구축

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam
from keras.layers import Dropout

model = Sequential()

model.add(Dense(64,input_shape=(input_dim,),activation='relu')) # input_shape => 입력 데이터의 형태를 알 수 있게 해줌 
model.add(Dropout(0.2))
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1)) # 활성화 함수 없음 

model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse']) # 회귀 문제에서 손실함수는 mse <=> 분류 문제 

model.summary()
# Out:
# C:\Users\tansy\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_82 (Dense)                     │ (None, 64)                  │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_83 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_84 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,625 (10.25 KB)
#  Trainable params: 2,625 (10.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
N_EPOCHS = 50

history=model.fit(x=X_train, y=y_train, epochs=N_EPOCHS, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 537.8619 - mse: 537.8619 - val_loss: 85.4636 - val_mse: 85.4636
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 247.9378 - mse: 247.9378 - val_loss: 106.4655 - val_mse: 106.4655
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 197.7853 - mse: 197.7853 - val_loss: 67.2109 - val_mse: 67.2109
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 178.1241 - mse: 178.1241 - val_loss: 74.6708 - val_mse: 74.6708
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 175.2509 - mse: 175.2509 - val_loss: 109.7076 - val_mse: 109.7076
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 120.7338 - mse: 120.7338 - val_loss: 81.4159 - val_mse: 81.4159
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 138.4285 - mse: 138.4285 - val_loss: 73.5252 - val_mse: 73.5252
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 139.9523 - mse: 139.9523 - val_loss: 60.4329 - val_mse: 60.4329
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 105.8254 - mse: 105.8254 - val_loss: 72.4621 - val_mse: 72.4621
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 109.6966 - mse: 109.6966 - val_loss: 74.2438 - val_mse: 74.2438
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 97.4776 - mse: 97.4776 - val_loss: 83.1517 - val_mse: 83.1517
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 109.1514 - mse: 109.1514 - val_loss: 70.7692 - val_mse: 70.7692
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 108.0158 - mse: 108.0158 - val_loss: 65.2758 - val_mse: 65.2758
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 98.1076 - mse: 98.1076 - val_loss: 92.8725 - val_mse: 92.8725
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 96.8323 - mse: 96.8323 - val_loss: 80.5470 - val_mse: 80.5470
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 86.8310 - mse: 86.8310 - val_loss: 90.1970 - val_mse: 90.1970
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 102.8841 - mse: 102.8841 - val_loss: 104.4184 - val_mse: 104.4184
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 90.1609 - mse: 90.1609 - val_loss: 98.2181 - val_mse: 98.2181
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 91.6466 - mse: 91.6466 - val_loss: 67.4402 - val_mse: 67.4402
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 95.2636 - mse: 95.2636 - val_loss: 79.8521 - val_mse: 79.8521
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 78.8726 - mse: 78.8726 - val_loss: 96.1537 - val_mse: 96.1537
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 79.3304 - mse: 79.3304 - val_loss: 84.7984 - val_mse: 84.7984
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 79.6827 - mse: 79.6827 - val_loss: 63.4247 - val_mse: 63.4247
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 75.5291 - mse: 75.5291 - val_loss: 85.2800 - val_mse: 85.2800
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 75.7515 - mse: 75.7515 - val_loss: 65.2738 - val_mse: 65.2738
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 79.4685 - mse: 79.4685 - val_loss: 73.3706 - val_mse: 73.3706
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 80.2955 - mse: 80.2955 - val_loss: 82.3154 - val_mse: 82.3154
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 82.5180 - mse: 82.5180 - val_loss: 103.4459 - val_mse: 103.4459
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 88.9142 - mse: 88.9142 - val_loss: 60.3769 - val_mse: 60.3769
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 75.1867 - mse: 75.1867 - val_loss: 72.2396 - val_mse: 72.2396
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 75.1348 - mse: 75.1348 - val_loss: 55.7146 - val_mse: 55.7146
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 72.8737 - mse: 72.8737 - val_loss: 78.0311 - val_mse: 78.0311
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 86.8105 - mse: 86.8105 - val_loss: 75.6323 - val_mse: 75.6323
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 74.8829 - mse: 74.8829 - val_loss: 80.2380 - val_mse: 80.2380
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 68.6652 - mse: 68.6652 - val_loss: 76.4206 - val_mse: 76.4206
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 59.5707 - mse: 59.5707 - val_loss: 61.7432 - val_mse: 61.7432
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 75.2878 - mse: 75.2878 - val_loss: 68.9963 - val_mse: 68.9963
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 79.4172 - mse: 79.4172 - val_loss: 83.3634 - val_mse: 83.3634
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 68.9706 - mse: 68.9706 - val_loss: 59.3503 - val_mse: 59.3503
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 83.8769 - mse: 83.8769 - val_loss: 66.1229 - val_mse: 66.1229
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 75.7508 - mse: 75.7508 - val_loss: 60.9108 - val_mse: 60.9108
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 64.6985 - mse: 64.6985 - val_loss: 55.1497 - val_mse: 55.1497
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 76.1973 - mse: 76.1973 - val_loss: 60.3014 - val_mse: 60.3014
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 68.1431 - mse: 68.1431 - val_loss: 56.6574 - val_mse: 56.6574
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 71.3071 - mse: 71.3071 - val_loss: 75.0213 - val_mse: 75.0213
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 76.8234 - mse: 76.8234 - val_loss: 62.5236 - val_mse: 62.5236
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 66.9380 - mse: 66.9380 - val_loss: 60.2397 - val_mse: 60.2397
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 75.1344 - mse: 75.1344 - val_loss: 54.4379 - val_mse: 54.4379
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 63.8281 - mse: 63.8281 - val_loss: 51.2061 - val_mse: 51.2061
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 77.4942 - mse: 77.4942 - val_loss: 54.8627 - val_mse: 54.8627
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %% [markdown]
# # 모델 평가

# %%
# loss 체크
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# mse체크 
mse =history.history['mse']
val_mse =history.history['val_mse']
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), mse, 'y', label='Training mse')
plt.plot(range(N_EPOCHS), val_mse, 'r', label='Validation mse')
plt.title('Training and validation mse')
plt.xlabel('Epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 53.5746 - mse: 53.5746
# [54.862735748291016, 54.862735748291016]

# %% [markdown]
# # 실제값 예측값 비교(산점도)

# %%
#y_test = np.argmax(y_test, axis=1) 원 핫 인코딩 => 정수값으로 변환함 
#y_pred = np.argmax(y_pred, axis=1) 
y_test.shape, y_pred.shape
plt.figure(figsize=(10,5)) 
plt.scatter(X_test[:, 2], y_test, label='y_test') # SkinThickness는 3번째 열, [:, 2]는 모든 행중 2번째 열을 선택하라는 뜻
plt.scatter(X_test[:, 2], y_pred, c='red' ,label="y_pred") # 예측값 분포
plt.legend() # 범례 표시 
plt.show()
